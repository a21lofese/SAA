# %% [markdown]
# ## Cargar el dataset

# %%
import pandas as pd
df = pd.read_csv("csv/rl1.csv")
df.head()
# Out:
#     x    y
# 0  24  133
# 1  35  187
# 2  36  189
# 3  36  183
# 4  42  220

# %% [markdown]
# ## Preparamiento de los datos

# %%
X, y = df[['x']], df['y']

# %% [markdown]
# ## Visualización de los datos

# %%
from matplotlib import pyplot as plt

plt.scatter(df['x'], df['y'], label='Datos')
plt.title('Distribución de los datos')
plt.show()

# %%
import seaborn as sns

sns.lmplot(data=df, x='x', y='y', order=1)

# %% [markdown]
# ## Preparación del conjunto de datos

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, random_state=42)

# %% [markdown]
# ## Creación del modelo

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X_train, y_train)

print(f"Coeficiente: {model.coef_}")
print(f"Intercepto: {model.intercept_}")
# Out:
# Coeficiente: [4.94130312]
# Intercepto: 35.25382937781956

# %% [markdown]
# ## Predicción

# %%
y_pred = model.predict(X_test)

from sklearn import metrics

print(f"MSE: {metrics.mean_squared_error(y_test, y_pred)}")
print(f"R2: {metrics.r2_score(y_test, y_pred)}")
print(f"var: {metrics.explained_variance_score(y_test, y_pred)}")
# Out:
# MSE: 4116.05205093945
# R2: 0.9917997876418883
# var: 0.9920078230589233

# %% [markdown]
# ## Visualización de la predicción

# %%
plt.scatter(X_test, y_test, label='Datos')
plt.plot(X_test, y_pred, color='red', label='Predicción')
plt.title('Predicción')
plt.legend()
plt.show()
